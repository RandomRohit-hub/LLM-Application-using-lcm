# %%
# !pip install langchain
# Out:
# Requirement already satisfied: langchain in c:\users\fakee\anaconda3\lib\site-packages (0.3.24)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.55 in c:\users\fakee\anaconda3\lib\site-packages (from langchain) (0.3.55)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\fakee\anaconda3\lib\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\fakee\anaconda3\lib\site-packages (from langchain) (0.3.33)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\fakee\anaconda3\lib\site-packages (from langchain) (2.8.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\fakee\anaconda3\lib\site-packages (from langchain) (2.0.34)
# Requirement already satisfied: requests<3,>=2 in c:\users\fakee\anaconda3\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\fakee\anaconda3\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\fakee\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (8.2.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\fakee\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\fakee\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\fakee\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.55->langchain) (4.11.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\fakee\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\fakee\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\fakee\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\fakee\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\fakee\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\fakee\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\fakee\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\fakee\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\fakee\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fakee\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\fakee\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in c:\users\fakee\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\fakee\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\fakee\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\fakee\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\fakee\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.55->langchain) (2.1)
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv
load_dotenv()

import openai
openai.api_key=os.getenv("OPEN_API_KEY")

groq_api_key=os.getenv("groq_api")
# groq_api_key
# Out:
#   Cell In[17], line 9
#     //groq_api_key
#     ^
# SyntaxError: invalid syntax

# %%
# !pip install langchain-groq
# Out:
# Requirement already satisfied: langchain-groq in c:\users\fakee\anaconda3\lib\site-packages (0.3.2)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.49 in c:\users\fakee\anaconda3\lib\site-packages (from langchain-groq) (0.3.58)
# Requirement already satisfied: groq<1,>=0.4.1 in c:\users\fakee\anaconda3\lib\site-packages (from langchain-groq) (0.24.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\fakee\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\fakee\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\fakee\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\fakee\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (2.8.2)
# Requirement already satisfied: sniffio in c:\users\fakee\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\fakee\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (4.11.0)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\fakee\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.49->langchain-groq) (0.3.33)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\fakee\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.49->langchain-groq) (8.2.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\fakee\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.49->langchain-groq) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\fakee\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.49->langchain-groq) (6.0.1)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\fakee\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.49->langchain-groq) (24.1)
# Requirement already satisfied: idna>=2.8 in c:\users\fakee\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq) (3.7)
# Requirement already satisfied: certifi in c:\users\fakee\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\fakee\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\fakee\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\fakee\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.49->langchain-groq) (2.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\fakee\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.49->langchain-groq) (3.10.16)
# Requirement already satisfied: requests<3,>=2 in c:\users\fakee\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.49->langchain-groq) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\fakee\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.49->langchain-groq) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\fakee\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.49->langchain-groq) (0.23.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\fakee\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\fakee\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\fakee\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.49->langchain-groq) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\fakee\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.49->langchain-groq) (2.2.3)
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_openai import ChatOpenAI
from langchain_groq import ChatGroq

model=ChatGroq(model="gemma2-9b-it",groq_api_key=groq_api_key)
model
# Out:
# ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x000001F3C93ED910>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001F3C93EEB40>, model_name='gemma2-9b-it', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
# !pip install langchain_core
# Out:
# Requirement already satisfied: langchain_core in c:\users\fakee\anaconda3\lib\site-packages (0.3.58)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\fakee\anaconda3\lib\site-packages (from langchain_core) (0.3.33)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\fakee\anaconda3\lib\site-packages (from langchain_core) (8.2.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\fakee\anaconda3\lib\site-packages (from langchain_core) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\fakee\anaconda3\lib\site-packages (from langchain_core) (6.0.1)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\fakee\anaconda3\lib\site-packages (from langchain_core) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\fakee\anaconda3\lib\site-packages (from langchain_core) (4.11.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in c:\users\fakee\anaconda3\lib\site-packages (from langchain_core) (2.8.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\fakee\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain_core) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\fakee\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain_core) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\fakee\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain_core) (3.10.16)
# Requirement already satisfied: requests<3,>=2 in c:\users\fakee\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain_core) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\fakee\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain_core) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\fakee\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain_core) (0.23.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\fakee\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.5.2->langchain_core) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\fakee\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.5.2->langchain_core) (2.20.1)
# Requirement already satisfied: anyio in c:\users\fakee\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_core) (4.2.0)
# Requirement already satisfied: certifi in c:\users\fakee\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_core) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\fakee\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_core) (1.0.2)
# Requirement already satisfied: idna in c:\users\fakee\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_core) (3.7)
# Requirement already satisfied: sniffio in c:\users\fakee\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_core) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\fakee\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_core) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\fakee\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain_core) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\fakee\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain_core) (2.2.3)
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_core.messages import HumanMessage,SystemMessage

message=[
    SystemMessage(content='Translate the following from english to french'),
    HumanMessage(content="  Hello! How are you     ")
]

model.invoke(message)
# Out:
# AIMessage(content='Bonjour ! Comment allez-vous ? \n', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 23, 'total_tokens': 34, 'completion_time': 0.02, 'prompt_time': 0.002184217, 'queue_time': 0.245095117, 'total_time': 0.022184217}, 'model_name': 'gemma2-9b-it', 'system_fingerprint': 'fp_10c08bf97d', 'finish_reason': 'stop', 'logprobs': None}, id='run--d572b3ae-7274-40c4-a943-034532df7f23-0', usage_metadata={'input_tokens': 23, 'output_tokens': 11, 'total_tokens': 34})
